# %% [markdown]
# # Read the Pew.txt file as analyze some of the data

# %% [markdown]
# We have a Pew.txt file that was exported from the SPSS file from Paul.
#
# See if we can parse it and visualize some of the data.

# %%
import pandas as pd
pd.set_printoptions(max_columns=0)
# Out:
# /Library/Frameworks/Python.framework/Versions/7.3/lib/python2.7/site-packages/pandas/core/format.py:1653: FutureWarning: set_printoptions is deprecated, use set_option instead
#   FutureWarning)

# %% [markdown]
# Read into dataframe.

# %%
#pew = pd.read_csv('data/Pew.txt',delimiter=' ', dtype={'fips':object})
#pew = pd.read_csv('data/Pew.txt',delimiter=' ', dtype={'fips':np.character})
#pew = pd.read_csv('data/Pew.txt',delimiter=' ', dtype={'race':np.character})
pew = pd.read_csv('data/Pew.txt',delimiter=' ', dtype={'race':object,'hisp':object,'educ':object,'partyln':object,'party':object})
#pew = pd.read_csv('data/Pew.txt',delimiter=' ')

# %%
pew.dtypes
# Out:
# id            int64
# rid         float64
# weight      float64
# year          int64
# survey       object
# date        float64
# language     object
# age           int64
# age2         object
# sex          object
# race         object
# hisp         object
# racethn      object
# educ         object
# income       object
# income2      object
# fips        float64
# state       float64
# usr          object
# density     float64
# party        object
# partyln      object
# partysum     object
# regvoter    float64
# dtype: object

# %%
pew.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2 entries, 0 to 1
# Data columns (total 24 columns):
# id          2  non-null values
# rid         2  non-null values
# weight      2  non-null values
# year        2  non-null values
# survey      2  non-null values
# date        0  non-null values
# language    2  non-null values
# age         2  non-null values
# age2        2  non-null values
# sex         2  non-null values
# race        2  non-null values
# hisp        0  non-null values
# racethn     0  non-null values
# educ        2  non-null values
# income      0  non-null values
# income2     2  non-null values
# fips        0  non-null values
# state       2  non-null values
# usr         2  non-null values
# density     0  non-null values
# party       2  non-null values
# partyln     0  non-null values
# partysum    2  non-null values
# regvoter    0  non-null values
# dtypes: float64(11), int64(3), object(10)

# %% [markdown]
# Some basic summary statistics.

# %%
pew.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, count to max
# Data columns (total 14 columns):
# id          8  non-null values
# rid         8  non-null values
# weight      8  non-null values
# year        8  non-null values
# date        8  non-null values
# age         8  non-null values
# hisp        8  non-null values
# educ        8  non-null values
# fips        8  non-null values
# state       8  non-null values
# density     8  non-null values
# party       8  non-null values
# partyln     8  non-null values
# regvoter    8  non-null values
# dtypes: float64(14)

# %%
pew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 442262 entries, 0 to 442261
# Data columns (total 24 columns):
# id          442262  non-null values
# rid         389963  non-null values
# weight      441892  non-null values
# year        442262  non-null values
# survey      442262  non-null values
# date        382454  non-null values
# language    442262  non-null values
# age         442262  non-null values
# age2        442262  non-null values
# sex         442262  non-null values
# race        440983  non-null values
# hisp        422327  non-null values
# racethn     422480  non-null values
# educ        440980  non-null values
# income      376234  non-null values
# income2     442262  non-null values
# fips        319442  non-null values
# state       428020  non-null values
# usr         442262  non-null values
# density     130895  non-null values
# party       436889  non-null values
# partyln     428337  non-null values
# partysum    442262  non-null values
# regvoter    305512  non-null values
# dtypes: float64(11), int64(3), object(10)

# %% [markdown]
# ## Looking at each column

# %% [markdown]
# ### Dates

# %%
pew.year.hist()

# %% [markdown]
# There are lots of surveys!

# %%
print len(pew.survey.value_counts())
print pew.survey.value_counts().head(2)
print pew.survey.value_counts().tail(2)
# Out:
# 276
# Decout00    5719
# Typo99      3973
# dtype: int64
# AprNII04     790
# Janomni02    406
# dtype: int64

# %%
pew[pew.survey=='Heat4B']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 24 columns):
# id          0  non-null values
# rid         0  non-null values
# weight      0  non-null values
# year        0  non-null values
# survey      0  non-null values
# date        0  non-null values
# language    0  non-null values
# age         0  non-null values
# age2        0  non-null values
# sex         0  non-null values
# race        0  non-null values
# hisp        0  non-null values
# racethn     0  non-null values
# educ        0  non-null values
# income      0  non-null values
# income2     0  non-null values
# fips        0  non-null values
# state       0  non-null values
# usr         0  non-null values
# density     0  non-null values
# party       0  non-null values
# partyln     0  non-null values
# partysum    0  non-null values
# regvoter    0  non-null values
# dtypes: float64(12), int64(3), object(9)

# %% [markdown]
# We could parse these *date* strings.  They look like mddyy.

# %%
pew.date.value_counts()[:5]
# Out:
# 31901     1478
# 80101     1277
# 91299     1205
# 0         1107
# 101708     922
# dtype: int64

# %%
#pew['date_new'] = pew.date.apply(lambda d:

# %% [markdown]
# ### Demographics

# %%
pew.language.value_counts()
# Out:
# English only           348561
# English and Spanish     93701
# dtype: int64

# %% [markdown]
# These ages seem strange.

# %%
pew.age.value_counts()[:5]
# Out:
# 50    11054
# 40     9876
# 18     9210
# 45     9207
# 42     9137
# dtype: int64

# %% [markdown]
# There are spikes at regular intervals, e.g., 45 and 50, and at ages with special significance, e.g. 18.  Perhaps some surveys were done on people with specific ages, or the people or the poll data collector was rounding down (or up).

# %%
pew.age.hist(bins=100)

# %%
pew.age2.value_counts()
# Out:
# 30-49                159056
# 50-64                111068
# 65+                   88069
# 18-29                 77350
# DK\Refused             6563
# Missing\not asked       156
# dtype: int64

# %%
pew.sex.value_counts()
# Out:
# Female    230365
# Male      211897
# dtype: int64

# %% [markdown]
# Females are *more* likely to answer DK\Refused.

# %%
pew[pew.age2 == 'DK\Refused'].sex.value_counts()
# Out:
# Female    4293
# Male      2270
# dtype: int64

# %%
pew.racethn.value_counts()
# Out:
# White non-Hisp    327168
# Black non-Hisp     39701
# Hispanic           28933
# Other              21586
# DK/Ref              5092
# dtype: int64

# %% [markdown]
# It would be good to have dictionary for these category numbers into a file that could be joined with this Pew.txt file so we know what the values, e.g., *2*, mean.

# %%
pew.hisp.value_counts()
# Out:
# 2    389830
# 1     28933
# 9      3561
# 8         2
# 0         1
# dtype: int64

# %%
pew.race.value_counts()
# Out:
# 1    358296
# 2     43238
# 4     22943
# 3     10041
# 9      6457
# 8         7
# 0         1
# dtype: int64

# %%
#pew[pew.race==1].head()

# %% [markdown]
# Why are there two *income* columns?

# %%
pew.income.value_counts()
# Out:
# $50,000 to $74,999    56115
# DK\Refused            51980
# $20,000 to $29,999    44149
# $30,000 to $39,999    42308
# $75,000 to $99,999    37979
# $40,000 to $49,999    36696
# $10,000 to $19,999    36216
# $100k to $149,999     32736
# less than $10,000     22826
# $150,000+             15229
# dtype: int64

# %%
pew.income2.value_counts()
# Out:
# $75,000+              106621
# $30,000 to $49,999     79004
# Missing\not asked      77028
# less than $20,000      59042
# $50,000 to $74,999     56115
# $20,000 to $29,999     44149
# DK\Refused             20303
# dtype: int64

# %% [markdown]
# ### Locations

# %%
print pew.fips.value_counts().head()
print pew.fips.value_counts().tail()
#pew.fips.value_counts().plot()
# Out:
# 6037     6718
# 17031    4058
# 4013     3084
# 48201    2648
# 6073     2526
# dtype: int64
# 31009    1
# 72021    1
# 20083    1
# 13307    1
# 31171    1
# dtype: int64

# %% [markdown]
# *state* is present whenever *fips* is present.  So, just get the county from *fips* whenever it is available.

# %%
print 'state but not fips:', len(pew[pew.state.notnull() & pew.fips.isnull()])
print 'fips but not state:', len(pew[pew.state.isnull() & pew.fips.notnull()])
# Out:
# state but not fips:
# 108578
# fips but not state: 0

# %% [markdown]
# Get the FIPS county code from the 5-digit FIPS 6-4 code.

# %%
pew['fips_county'] = pew.fips.apply(lambda code: code%1000 if code != NaN else NaN)
pew[['state','fips','fips_county']][pew.fips_county.notnull()].sort('fips').tail(2)
# Out:
#         state   fips  fips_county
# 442260     72  72021           21
# 442261     78  78010           10

# %% [markdown]
# ####FIPS

# %% [markdown]
# A separate file with FIPS codes.  Use it to get state and county names.

# %%
# !head -n 2 data/US_FIPS_Codes.csv
fips = pd.read_csv('data/US_FIPS_Codes.csv')
fips.head(2)
# Out:
# State,County Name,FIPS State,FIPS County
# Alabama,Autauga,01,001
#      State County Name  FIPS State  FIPS County
# 0  Alabama     Autauga           1            1
# 1  Alabama     Baldwin           1            3

# %%
fips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3142 entries, 0 to 3141
# Data columns (total 4 columns):
# State          3142  non-null values
# County Name    3142  non-null values
# FIPS State     3142  non-null values
# FIPS County    3142  non-null values
# dtypes: int64(2), object(2)

# %%
#fips['FIPS_6-4'] = fips.apply(lambda row: "%02d%03d"%(row['FIPS State'],row['FIPS County']), axis=1)
#fips.head()

# %% [markdown]
# Get the state names.

# %%
fips_states = fips[['State','FIPS State']].drop_duplicates()
fips_states.head(2)
# Out:
#       State  FIPS State
# 0   Alabama           1
# 67   Alaska           2

# %%
pew2 = pew.merge(fips_states, how='left', left_on='state', right_on='FIPS State')
pew2['state_name'] = pew2.State
pew2[pew2.fips.notnull()].sort('fips').head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2 entries, 99092 to 99241
# Data columns (total 28 columns):
# id             2  non-null values
# rid            0  non-null values
# weight         2  non-null values
# year           2  non-null values
# survey         2  non-null values
# date           2  non-null values
# language       2  non-null values
# age            2  non-null values
# age2           2  non-null values
# sex            2  non-null values
# race           2  non-null values
# hisp           2  non-null values
# racethn        2  non-null values
# educ           2  non-null values
# income         2  non-null values
# income2        2  non-null values
# fips           2  non-null values
# state          2  non-null values
# usr            2  non-null values
# density        0  non-null values
# party          2  non-null values
# partyln        2  non-null values
# partysum       2  non-null values
# regvoter       2  non-null values
# fips_county    2  non-null values
# State          2  non-null values
# FIPS State     2  non-null values
# state_name     2  non-null values
# dtypes: float64(13), int64(3), object(12)

# %% [markdown]
# Get the county names.

# %%
pew3 = pew2.merge(fips, how='left', left_on=['state','fips_county'], right_on=['FIPS State','FIPS County'])
pew3[['state','fips','fips_county','state_name','County Name']][pew3.fips.notnull()].sort('fips').tail(5)
#pew3[pew3.fips.notnull()].tail(5)
# Out:
#         state   fips  fips_county state_name County Name
# 347105     56  56045           45    Wyoming      Weston
# 347106     56  56045           45    Wyoming      Weston
# 347107     56  56045           45    Wyoming      Weston
# 442260     72  72021           21        NaN         NaN
# 442261     78  78010           10        NaN         NaN

# %%
pew3.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 0 to 4
# Data columns (total 32 columns):
# id              5  non-null values
# rid             5  non-null values
# weight          5  non-null values
# year            5  non-null values
# survey          5  non-null values
# date            0  non-null values
# language        5  non-null values
# age             5  non-null values
# age2            5  non-null values
# sex             5  non-null values
# race            5  non-null values
# hisp            0  non-null values
# racethn         0  non-null values
# educ            5  non-null values
# income          0  non-null values
# income2         5  non-null values
# fips            0  non-null values
# state           5  non-null values
# usr             5  non-null values
# density         0  non-null values
# party           5  non-null values
# partyln         0  non-null values
# partysum        5  non-null values
# regvoter        0  non-null values
# fips_county     0  non-null values
# State_x         5  non-null values
# FIPS State_x    5  non-null values
# state_name      5  non-null values
# State_y         0  non-null values
# County Name     0  non-null values
# FIPS State_y    0  non-null values
# FIPS County     0  non-null values
# dtypes: float64(15), int64(3), object(14)

# %% [markdown]
# #### Urban suburvan rural?

# %%
pew.usr.value_counts()
# Out:
#      152070
# S    139778
# U     82713
# R     60954
# 2      3327
# 1      1891
# 3      1529
# dtype: int64

# %% [markdown]
# ### Politics

# %%
pew.party.value_counts()
# Out:
# 3    140659
# 2    140233
# 1    127981
# 4     14636
# 9     11067
# 5      2312
# 0         1
# dtype: int64

# %%
pew.partyln.value_counts()
# Out:
# 0    262804
# 2     59109
# 1     55178
# 9     51246
# dtype: int64

# %% [markdown]
# Fairly well balanced between those leaning Dem and those leaning Rep.

# %%
pew.partysum.value_counts()
# Out:
# Dem/ln D                          199342
# Rep/ln R                          183159
# No leaning                         54387
# Party or Partyln not available      5374
# dtype: int64

# %% [markdown]
# All are registered voters?

# %%
pew.regvoter.value_counts()
# Out:
# 1    305512
# dtype: int64

# %%
print len(pew.regvoter)
print len(pew[pew.regvoter.isnull()])
# Out:
# 442262
# 136750

# %%
pew[pew.regvoter.isnull()].year.hist(bins=20)

# %%
pew[pew.regvoter.isnull() == False].year.hist(bins=20)

# %%
pew3[pew3['County Name'].notnull()].head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 4582 to 4586
# Data columns (total 32 columns):
# id              5  non-null values
# rid             5  non-null values
# weight          5  non-null values
# year            5  non-null values
# survey          5  non-null values
# date            5  non-null values
# language        5  non-null values
# age             5  non-null values
# age2            5  non-null values
# sex             5  non-null values
# race            5  non-null values
# hisp            5  non-null values
# racethn         5  non-null values
# educ            5  non-null values
# income          5  non-null values
# income2         5  non-null values
# fips            5  non-null values
# state           5  non-null values
# usr             5  non-null values
# density         0  non-null values
# party           5  non-null values
# partyln         5  non-null values
# partysum        5  non-null values
# regvoter        3  non-null values
# fips_county     5  non-null values
# State_x         5  non-null values
# FIPS State_x    5  non-null values
# state_name      5  non-null values
# State_y         5  non-null values
# County Name     5  non-null values
# FIPS State_y    5  non-null values
# FIPS County     5  non-null values
# dtypes: float64(16), int64(3), object(13)

# %% [markdown]
# ###Clean up the data frame

# %%
#pew3['FIPS_6-4'] = pew.apply(lambda row: "%02f%03f"%(row['state'],row['fips_county']) if ((row['state']!=NaN) and (row['fips_county']!=NaN)) else NaN,axis=1)

# %%
pew4 = pew3.copy()
del pew4['fips']
#del pew4['state']
#del pew4['fips_county']
del pew4['State_x']
del pew4['FIPS State_x']
del pew4['FIPS State_y']
del pew4['State_y']
del pew4['FIPS County']
pew4 = pew4.rename(columns={'County Name':'county_name',
                            'fips_county':'fipsco',
                            'state':'fipsst'})
pew4[pew4.county_name.notnull()].head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 4582 to 4586
# Data columns (total 26 columns):
# id             5  non-null values
# rid            5  non-null values
# weight         5  non-null values
# year           5  non-null values
# survey         5  non-null values
# date           5  non-null values
# language       5  non-null values
# age            5  non-null values
# age2           5  non-null values
# sex            5  non-null values
# race           5  non-null values
# hisp           5  non-null values
# racethn        5  non-null values
# educ           5  non-null values
# income         5  non-null values
# income2        5  non-null values
# fipsst         5  non-null values
# usr            5  non-null values
# density        0  non-null values
# party          5  non-null values
# partyln        5  non-null values
# partysum       5  non-null values
# regvoter       3  non-null values
# fipsco         5  non-null values
# state_name     5  non-null values
# county_name    5  non-null values
# dtypes: float64(11), int64(3), object(12)

# %% [markdown]
# ## Codebook

# %% [markdown]
# Take a copy of the codes and meanings in CSV form drawn from the Merge Codebook PDF file, and merge its information with the pew data so we can see what the meanings of the values.

# %%
codes = pd.read_csv('data/Merge_Codebook.csv').groupby('column')
codes.head(2)
# Out:
#              column code                  meaning
# column
# educ    8      educ    1    Less than high school
#         9      educ    2  High school, incomplete
# hisp    5      hisp    1                      Yes
#         6      hisp    2                       No
# party   21    party    1               Republican
#         22    party    2                 Democrat
# partyln 27  partyln    0        Missing/not asked
#         28  partyln    1          Lean Republican
# race    0      race    1                    White
#         1      race    2                    Black
# usr     17      usr    U                   Urban
#         18      usr    S                Suburban

# %%
code_columns = dict(list(codes))
print code_columns['party'].dtypes
code_columns['party'].head()
# Out:
# column     object
# code       object
# meaning    object
# dtype: object
#    column code        meaning
# 21  party    1     Republican
# 22  party    2       Democrat
# 23  party    3    Independent
# 24  party    4  No Preference
# 25  party    5          Other

# %% [markdown]
# #### Debugging

# %%
column,df_orig = code_columns.items()[1]
df = df_orig.copy()
print column
del df['column']
df = df.rename(columns={'code':column})
print df.dtypes
df
# Out:
# race
# race       object
# meaning    object
# dtype: object
#   race      meaning
# 0    1        White
# 1    2        Black
# 2    3        Asian
# 3    4  Other/Mixed
# 4    9   DK/Refused

# %%
pew5 = pew4.copy()
pew5 = pew5[['id','rid',column]]
pt = pew5[pew5[column].notnull()][-5:]
print pt
#pt[column] = pt[column].astype(object)
pt[column] = pt[column].astype(np.character)
print pt.dtypes
print pt
# Out:
#             id     rid race
# 442257  205571  202295    1
# 442258  205572  101059    1
# 442259  205573  203215    3
# 442260  442261  100936    1
# 442261  442262  100546    2
# id        int64
# rid     float64
# race     object
# dtype: object
#             id     rid race
# 442257  205571  202295    1
# 442258  205572  101059    1
# 442259  205573  203215    3
# 442260  442261  100936    1
# 442261  442262  100546    2

# %%
pt.merge(df, how='left')
# Out:
#        id     rid race meaning
# 0  205571  202295    1   White
# 1  205572  101059    1   White
# 2  442261  100936    1   White
# 3  205573  203215    3   Asian
# 4  442262  100546    2   Black

# %%
#df = pd.DataFrame({'partyln':['0','1','2','9'], 'meaning':['m0','m1','m2','m9']})
#df

# %% [markdown]
# #### Do the merge.

# %%
pew5 = pew4.copy().sort('id')
for column,df_orig in code_columns.items():
    #pew5 = pew4.copy().sort('id')
    #pew5 = pew5[['id','rid',column]]
    
    #pew5 = pew5[pew5[column].notnull()][-5:]
    
    df = df_orig.copy()
    print "#"*40
    print column
    del df['column']
    df2 = df.rename(columns={'code':column})
    print df2
    print df2.dtypes
    
    #print "#"*20
    #pew5 = pew5.merge(df,how='left', left_on=column, right_on='code')
    #print pew5[column].dtype
    #print pew5[pew5[column].notnull()].tail()
    
    #print "#"*20
    #pew5[column] = pew5[column].astype(object)
    pew5[column] = pew5[column].astype(np.character)
    #print pew5[column].dtype
    #print pew5[pew5[column].notnull()].tail()
    
    print "#"*20
    #pew5 = pew5.merge(df2,how='left',on=column)
    pew5 = pew5.merge(df2,how='left')
    del pew5[column]
    #pew5 = pew5.rename(columns={'meaning':column+'_new'})
    pew5 = pew5.rename(columns={'meaning':column})
    
    pew5 = pew5.sort('id')
    print pew5[pew5[column].notnull()].tail()
# Out:
# ########################################
# partyln
#    partyln            meaning
# 27       0  Missing/not asked
# 28       1    Lean Republican
# 29       2      Lean Democrat
# 30       9           Other/DK
# partyln    object
# meaning    object
# dtype: object
# ####################
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 26 columns):
# id             0  non-null values
# rid            0  non-null values
# weight         0  non-null values
# year           0  non-null values
# survey         0  non-null values
# date           0  non-null values
# language       0  non-null values
# age            0  non-null values
# age2           0  non-null values
# sex            0  non-null values
# race           0  non-null values
# hisp           0  non-null values
# racethn        0  non-null values
# educ           0  non-null values
# income         0  non-null values
# income2        0  non-null values
# fipsst         0  non-null values
# usr            0  non-null values
# density        0  non-null values
# party          0  non-null values
# partysum       0  non-null values
# regvoter       0  non-null values
# fipsco         0  non-null values
# state_name     0  non-null values
# county_name    0  non-null values
# partyln        0  non-null values
# dtypes: float64(11), int64(3), object(12)
# ########################################
# race
#   race      meaning
# 0    1        White
# 1    2        Black
# 2    3        Asian
# 3    4  Other/Mixed
# 4    9   DK/Refused
# race       object
# meaning    object
# dtype: object
# ####################
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 26 columns):
# id             0  non-null values
# rid            0  non-null values
# weight         0  non-null values
# year           0  non-null values
# survey         0  non-null values
# date           0  non-null values
# language       0  non-null values
# age            0  non-null values
# age2           0  non-null values
# sex            0  non-null values
# hisp           0  non-null values
# racethn        0  non-null values
# educ           0  non-null values
# income         0  non-null values
# income2        0  non-null values
# fipsst         0  non-null values
# usr            0  non-null values
# density        0  non-null values
# party          0  non-null values
# partysum       0  non-null values
# regvoter       0  non-null values
# fipsco         0  non-null values
# state_name     0  non-null values
# county_name    0  non-null values
# partyln        0  non-null values
# race           0  non-null values
# dtypes: float64(10), int64(3), object(13)
# ########################################
# hisp
#   hisp     meaning
# 5    1         Yes
# 6    2          No
# 7    9  DK/Refused
# hisp       object
# meaning    object
# dtype: object
# ####################
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 26 columns):
# id             0  non-null values
# rid            0  non-null values
# weight         0  non-null values
# year           0  non-null values
# survey         0  non-null values
# date           0  non-null values
# language       0  non-null values
# age            0  non-null values
# age2           0  non-null values
# sex            0  non-null values
# racethn        0  non-null values
# educ           0  non-null values
# income         0  non-null values
# income2        0  non-null values
# fipsst         0  non-null values
# usr            0  non-null values
# density        0  non-null values
# party          0  non-null values
# partysum       0  non-null values
# regvoter       0  non-null values
# fipsco         0  non-null values
# state_name     0  non-null values
# county_name    0  non-null values
# partyln        0  non-null values
# race           0  non-null values
# hisp           0  non-null values
# dtypes: float64(9), int64(3), object(14)
# ########################################
# usr
#    usr            meaning
# 17   U             Urban
# 18   S          Suburban
# 19   R             Rural
# 20   0  Missing/not asked
# usr        object
# meaning    object
# dtype: object
# ####################
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 295732 to 295736
# Data columns (total 26 columns):
# id             5  non-null values
# rid            5  non-null values
# weight         5  non-null values
# year           5  non-null values
# survey         5  non-null values
# date           5  non-null values
# language       5  non-null values
# age            5  non-null values
# age2           5  non-null values
# sex            5  non-null values
# racethn        5  non-null values
# educ           5  non-null values
# income         5  non-null values
# income2        5  non-null values
# fipsst         5  non-null values
# density        5  non-null values
# party          5  non-null values
# partysum       5  non-null values
# regvoter       4  non-null values
# fipsco         5  non-null values
# state_name     5  non-null values
# county_name    5  non-null values
# partyln        0  non-null values
# race           0  non-null values
# hisp           0  non-null values
# usr            5  non-null values
# dtypes: float64(9), int64(3), object(14)
# ########################################
# party
#    party        meaning
# 21     1     Republican
# 22     2       Democrat
# 23     3    Independent
# 24     4  No Preference
# 25     5          Other
# 26     9             DK
# party      object
# meaning    object
# dtype: object
# ####################
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 26 columns):
# id             0  non-null values
# rid            0  non-null values
# weight         0  non-null values
# year           0  non-null values
# survey         0  non-null values
# date           0  non-null values
# language       0  non-null values
# age            0  non-null values
# age2           0  non-null values
# sex            0  non-null values
# racethn        0  non-null values
# educ           0  non-null values
# income         0  non-null values
# income2        0  non-null values
# fipsst         0  non-null values
# density        0  non-null values
# partysum       0  non-null values
# regvoter       0  non-null values
# fipsco         0  non-null values
# state_name     0  non-null values
# county_name    0  non-null values
# partyln        0  non-null values
# race           0  non-null values
# hisp           0  non-null values
# usr            0  non-null values
# party          0  non-null values
# dtypes: float64(8), int64(3), object(15)
# ########################################
# educ
#    educ                     meaning
# 8     1       Less than high school
# 9     2     High school, incomplete
# 10    3        High school graduate
# 11    4  Business, Technical, Trade
# 12    5                Some College
# 13    6            College graduate
# 14    7               Post-graduate
# 15    8        Post-graduate degree
# 16    9                  DK/Refused
# educ       object
# meaning    object
# dtype: object
# ####################
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 26 columns):
# id             0  non-null values
# rid            0  non-null values
# weight         0  non-null values
# year           0  non-null values
# survey         0  non-null values
# date           0  non-null values
# language       0  non-null values
# age            0  non-null values
# age2           0  non-null values
# sex            0  non-null values
# racethn        0  non-null values
# income         0  non-null values
# income2        0  non-null values
# fipsst         0  non-null values
# density        0  non-null values
# partysum       0  non-null values
# regvoter       0  non-null values
# fipsco         0  non-null values
# state_name     0  non-null values
# county_name    0  non-null values
# partyln        0  non-null values
# race           0  non-null values
# hisp           0  non-null values
# usr            0  non-null values
# party          0  non-null values
# educ           0  non-null values
# dtypes: float64(7), int64(3), object(16)

# %%
pew5.tail(100)
# Out:
#             id      rid    weight  year               survey    date  \
# 238442  442163   208415  1.980029  2013           Sept13Poli   90813
# 365625  442164    16074  1.328535  2000            Maypoli00   50400
# 435935  442165    39950  0.385490  2002            Midsept02   91202
# 91615   442166   110178  0.934714  2002            Janomni02   11402
# 435936  442167      883  0.814139  2002             Jannii02   11002
# 365626  442168     2540  2.281965  2007             JanNII07   11507
# 435937  442169     3954  0.818253  2007           AugRelig07     NaN
# 91616   442170     1342  0.325172  2008            May08Poli   52508
# 91617   442171   103008  0.866071  2010            Oct10Poli  101510
# 91618   442172   103011  0.374911  2010  Nov10 Post-Election  110710
# 238443  442173   103666  0.452351  2011         July11 Media   72411
# 238444  442174   210692  0.740412  2013           July13Poli   72113
# 365627  442175      NaN  1.255309  1999            Septnii99   91299
# 238445  442176    25367  1.157565  2000               June00   61900
# 365628  442177     1741  1.814242  2001          Septtrack01   92101
# 365629  442178    43581  0.731443  2002            Midsept02   91302
# 365630  442179     3177  1.152520  2002            Maromni02   31902
# 91619   442180    15464  1.066694  2002             Febnii02   21502
# 238446  442181    16897  1.764665  2003             NovNII03  112803
# 238447  442182    14273  0.818498  2003         AugNIIOmni03   81103
# 365631  442183      411       NaN  2003           JuneMeth03   62103
# 238448  442184    20628  0.657754  2003           AprTrack03   41203
# 365632  442185    13776  1.184480  2004            JanComm04  122703
# 129124  442186    27791  2.023609  2004          JuneVoter04   61004
# 91620   442187    29952  0.528897  2004            SeptNII04   91204
# 91621   442188     1415  1.113920  2005             MayNII05   51505
# 129125  442189      946  2.279523  2005            JuneNII05   61005
# 238449  442190     1967  0.610817  2005      SeptPolitical05   91105
# 435938  442191     1899  0.568740  2006            JuneNII06   61806
# 238450  442192     2178  0.858280  2006            JuneNII06   61906
# 365633  442193      320  0.908720  2006            SeptNii06   90606
# 238451  442194     1665  0.497000  2007           JulyPoli07   72907
# 238452  442195     2082  0.496000  2007           JulyPoli07   72907
# 238453  442196     2036  0.814572  2008            Feb08Poli   22408
# 238454  442197   201087  1.167781  2009           Dec09 Poli  121209
# 238455  442198  2020649  0.957560  2009          Apr09Values   41809
# 129126  442199   200912  3.192102  2010            Apr10Poli   42410
# 238456  442200   206088  1.882237  2010          June10Media   62210
# 238457  442201   103455  0.269760  2010            Oct10Poli  101510
# 435939  442202   200356  1.182173  2011          Nov11 Relig  110911
# 365634  442203   202640  1.065982  2011           Aug11 Poli   82111
# 91622   442204   107613  0.972207  2012          Apr12Values   41212
# 91623   442205   102350  0.340148  2013            Feb13Poli   21513
# 91624   442206   203465  0.974626  2013           Sept13Poli   90413
# 91625   442207      NaN  0.665428  1999             Jannii99   11599
# 91626   442208      NaN  1.266242  2000             Marnii00   31700
# 365635  442209    14867  1.192594  2001            Septapw01   82801
# 91627   442210   110249  0.544394  2002            Janomni02   11402
# 435940  442211     1280  1.087237  2002             Jannii02   11102
# 238458  442212    31622  0.649572  2003             OctNII03  101903
# 91628   442213    16532  0.838630  2003          JulyMedia03   62503
# 435941  442214      838  0.780785  2005             MayNII05   51305
# 382702  442215    51755  0.413914  2006        Immigration06   60224
# 238459  442216     1483  0.753677  2007             JanNII07   11307
# 91629   442217     2835  0.787766  2007           AugRelig07   81307
# 91630   442218     2422  0.844041  2008           May08Media   51908
# 238460  442219     1939  0.974554  2009       May09ScienceGP   50609
# 91631   442220   202004  0.752488  2010            Oct10Poli  101610
# 238461  442221   103895  0.567591  2010            Dec10Poli  120510
# 435942  442222   202236  0.589425  2011           Aug11 Poli   82011
# 91632   442223   103477  0.795756  2011          June11 Poli   61711
# 91633   442224   208725  1.005747  2013            Jan13Poli   11313
# 129127  442225   210535  1.553939  2013           June13Poli   61613
# 442259  442226   205693  1.538883  2013           Sept13Poli   90513
# 365636  442227     1941  1.088545  2001          Septtrack01   92101
# 238462  442228    15383  1.115653  2001            Septapw01   82801
# 382703  442229    42238  0.889398  2002            Lateoct02  102502
# 238463  442230     1197  1.196992  2002            Lateaug02   82303
# 91634   442231      867  0.512821  2003            SeptNII03   91803
# 129128  442232     2934  1.193566  2007             Values07   10607
# 238464  442233    80704  0.599596  2008        Sept08ForPoli   91408
# 382704  442234     1050  1.439099  2008        Dec08PoliEcon  120608
# 91635   442235    11133  0.550237  2008         MidOct08Poli  101808
# 238465  442236   104206  1.249600  2009          Aug09ReligB   82609
# 129129  442237  2001681  1.725415  2009          Apr09Values   42009
# 238466  442238   105188  0.567916  2010            Oct10Poli  101710
# 365637  442239   200720  1.906690  2010  Nov10 Post-Election  110510
# 91636   442240   104098  0.460872  2011           Apr11 Poli   40311
# 365638  442241   102978  0.495269  2011            Feb11Poli   20611
# 91637   442242   103623  0.321699  2012            Feb12Poli   21012
# 238467  442243    22827  1.030409  2002           Marrelig02   30502
# 129130  442244   110446  0.934714  2002            Janomni02   11402
# 365639  442245      868  1.671795  2003            SeptNII03   91803
# 238468  442246    19259  0.787573  2003           AprTrack03   41203
# 129131  442247     2055  2.284852  2004             MayPol04   50804
# 91638   442248     1439  0.530934  2005             MayNII05   51505
# 238469  442249      949  1.269959  2005            JuneNII05   61005
# 365640  442250     1802  0.806045  2006             AugNII06   81206
# 365641  442251   102065  0.745780  2009        Sept09PoliGap   91409
# 238470  442252   102276  0.486931  2010            Apr10Poli   42310
# 238471  442253   102836  1.206523  2011            Jan11Poli   10711
# 365642  442254   105941  0.789674  2010          June10Media   62210
# 365643  442255   106950  0.886843  2010          July10Relig   80210
# 365644  442256   203652  1.170374  2011    Oct11 Generations  100211
# 365645  442257   103003  0.921742  2012            Jan12comm   10612
# 238472  442258    75524  0.402589  2012        LateOct12Poli  102512
# 442260  442259   207459  0.639065  2013            Feb13Poli   21513
# 238473  442260   102983  0.863814  2013           July13Poli   71913
# 238474  442261   100936  2.095268  2013            Mar13Poli   31613
# 91639   442262   100546  1.409401  2012           Dec12 Poli  121207
#
#                    language  age        age2     sex         racethn  \
# 238442  English and Spanish   42       30-49  Female  White non-Hisp
# 365625         English only   55       50-64  Female  White non-Hisp
# 435935         English only   43       30-49    Male  White non-Hisp
# 91615          English only   58       50-64    Male  White non-Hisp
# 435936         English only   42       30-49  Female  White non-Hisp
# 365626         English only   26       18-29  Female  White non-Hisp
# 435937  English and Spanish   26       18-29  Female  White non-Hisp
# 91616          English only   69         65+  Female  White non-Hisp
# 91617          English only   36       30-49  Female  White non-Hisp
# 91618          English only   72         65+  Female  White non-Hisp
# 238443  English and Spanish   58       50-64  Female  White non-Hisp
# 238444  English and Spanish   61       50-64    Male          DK/Ref
# 365627         English only   38       30-49  Female  White non-Hisp
# 238445         English only   50       50-64    Male  White non-Hisp
# 365628         English only   65         65+    Male        Hispanic
# 365629         English only   51       50-64    Male  White non-Hisp
# 365630         English only   19       18-29  Female  White non-Hisp
# 91619          English only   29       18-29  Female  White non-Hisp
# 238446         English only   21       18-29  Female          DK/Ref
# 238447         English only   47       30-49  Female  White non-Hisp
# 365631         English only   55       50-64  Female  White non-Hisp
# 238448         English only   49       30-49    Male  White non-Hisp
# 365632         English only   42       30-49  Female  White non-Hisp
# 129124         English only   35       30-49  Female  White non-Hisp
# 91620          English only   51       50-64  Female  White non-Hisp
# 91621          English only   54       50-64    Male  White non-Hisp
# 129125         English only   50       50-64  Female  White non-Hisp
# 238449         English only   45       30-49    Male  White non-Hisp
# 435938         English only   62       50-64  Female  White non-Hisp
# 238450         English only   50       50-64  Female  White non-Hisp
# 365633         English only   51       50-64  Female  White non-Hisp
# 238451         English only   57       50-64  Female  White non-Hisp
# 238452         English only   70         65+    Male  White non-Hisp
# 238453         English only   47       30-49  Female  White non-Hisp
# 238454         English only   29       18-29  Female           Other
# 238455  English and Spanish   61       50-64    Male  White non-Hisp
# 129126         English only   51       50-64    Male        Hispanic
# 238456         English only   29       18-29  Female  White non-Hisp
# 238457         English only   55       50-64    Male  White non-Hisp
# 435939  English and Spanish   28       18-29    Male  White non-Hisp
# 365634  English and Spanish   53       50-64  Female  White non-Hisp
# 91622   English and Spanish   42       30-49  Female  White non-Hisp
# 91623   English and Spanish   45       30-49    Male  White non-Hisp
# 91624   English and Spanish   31       30-49    Male        Hispanic
# 91625          English only   47       30-49    Male  White non-Hisp
# 91626          English only   27       18-29    Male        Hispanic
# 365635         English only   46       30-49  Female  White non-Hisp
# 91627          English only   53       50-64    Male  White non-Hisp
# 435940         English only   57       50-64    Male           Other
# 238458         English only   54       50-64  Female  White non-Hisp
# 91628          English only   29       18-29    Male  White non-Hisp
# 435941         English only   40       30-49    Male  White non-Hisp
# 382702  English and Spanish   47       30-49    Male  White non-Hisp
# 238459         English only   41       30-49  Female  White non-Hisp
# 91629   English and Spanish   28       18-29    Male  White non-Hisp
# 91630          English only   62       50-64    Male  White non-Hisp
# 238460  English and Spanish   36       30-49  Female  White non-Hisp
# 91631          English only   43       30-49  Female  White non-Hisp
# 238461         English only   57       50-64    Male  White non-Hisp
# 435942  English and Spanish   44       30-49  Female  White non-Hisp
# 91632   English and Spanish   66         65+  Female  White non-Hisp
# 91633   English and Spanish   29       18-29  Female  White non-Hisp
# 129127  English and Spanish   21       18-29    Male        Hispanic
# 442259  English and Spanish   28       18-29  Female  White non-Hisp
# 365636         English only   41       30-49    Male  White non-Hisp
# 238462         English only   40       30-49  Female        Hispanic
# 382703         English only   28       18-29    Male  White non-Hisp
# 238463         English only   34       30-49  Female           Other
# 91634          English only   55       50-64  Female  White non-Hisp
# 129128  English and Spanish   67         65+  Female  White non-Hisp
# 238464         English only   47       30-49    Male  White non-Hisp
# 382704         English only   39       30-49    Male  White non-Hisp
# 91635          English only   54       50-64    Male  White non-Hisp
# 238465  English and Spanish   33       30-49  Female  White non-Hisp
# 129129  English and Spanish   42       30-49    Male  White non-Hisp
# 238466         English only   66         65+    Male  White non-Hisp
# 365637         English only   26       18-29    Male  White non-Hisp
# 91636          English only   68         65+  Female  White non-Hisp
# 365638  English and Spanish   83         65+  Female  White non-Hisp
# 91637   English and Spanish   84         65+  Female  White non-Hisp
# 238467         English only   27       18-29    Male  White non-Hisp
# 129130         English only   59       50-64  Female  White non-Hisp
# 365639         English only   37       30-49    Male  White non-Hisp
# 238468         English only   65         65+    Male  White non-Hisp
# 129131         English only   72         65+    Male        Hispanic
# 91638          English only   36       30-49  Female  White non-Hisp
# 238469         English only   81         65+  Female           Other
# 365640         English only   50       50-64  Female  White non-Hisp
# 365641         English only   61       50-64    Male  White non-Hisp
# 238470         English only   65         65+  Female  White non-Hisp
# 238471  English and Spanish   99  DK\Refused    Male          DK/Ref
# 365642         English only   75         65+  Female  White non-Hisp
# 365643  English and Spanish   81         65+    Male  White non-Hisp
# 365644  English and Spanish   64       50-64  Female  White non-Hisp
# 365645  English and Spanish   47       30-49  Female  White non-Hisp
# 238472  English and Spanish   61       50-64    Male  White non-Hisp
# 442260  English and Spanish   52       50-64  Female  White non-Hisp
# 238473  English and Spanish   49       30-49  Female  White non-Hisp
# 238474  English and Spanish   44       30-49    Male        Hispanic
# 91639   English and Spanish   30       30-49  Female  Black non-Hisp
#
#                     income             income2  fipsst  density  \
# 238442          DK\Refused          DK\Refused      56        1
# 365625   $100k to $149,999            $75,000+      56      NaN
# 435935                 NaN   Missing\not asked      56      NaN
# 91615   $50,000 to $74,999  $50,000 to $74,999      56      NaN
# 435936   $100k to $149,999            $75,000+      56      NaN
# 365626  $50,000 to $74,999  $50,000 to $74,999      56      NaN
# 435937  $20,000 to $29,999  $20,000 to $29,999      56      NaN
# 91616    $100k to $149,999            $75,000+      56        1
# 91617   $50,000 to $74,999  $50,000 to $74,999      56        1
# 91618   $10,000 to $19,999   less than $20,000      56        1
# 238443   $100k to $149,999            $75,000+      56        1
# 238444   $100k to $149,999            $75,000+      56        1
# 365627  $30,000 to $39,999  $30,000 to $49,999      56      NaN
# 238445          DK\Refused            $75,000+      56      NaN
# 365628          DK\Refused            $75,000+      56      NaN
# 365629                 NaN   Missing\not asked      56      NaN
# 365630  $10,000 to $19,999   less than $20,000      56      NaN
# 91619   $30,000 to $39,999  $30,000 to $49,999      56      NaN
# 238446          DK\Refused   Missing\not asked      56      NaN
# 238447  $10,000 to $19,999   less than $20,000      56      NaN
# 365631  $50,000 to $74,999  $50,000 to $74,999      56      NaN
# 238448  $75,000 to $99,999            $75,000+      56      NaN
# 365632  $30,000 to $39,999  $30,000 to $49,999      56      NaN
# 129124  $75,000 to $99,999            $75,000+      56      NaN
# 91620    $100k to $149,999            $75,000+      56      NaN
# 91621   $30,000 to $39,999  $30,000 to $49,999      56      NaN
# 129125  $20,000 to $29,999  $20,000 to $29,999      56      NaN
# 238449  $50,000 to $74,999  $50,000 to $74,999      56      NaN
# 435938  $50,000 to $74,999  $50,000 to $74,999      56      NaN
# 238450  $10,000 to $19,999   less than $20,000      56      NaN
# 365633  $40,000 to $49,999  $30,000 to $49,999      56      NaN
# 238451   $100k to $149,999            $75,000+      56      NaN
# 238452  $75,000 to $99,999            $75,000+      56      NaN
# 238453  $50,000 to $74,999  $50,000 to $74,999      56        1
# 238454   $100k to $149,999            $75,000+      56        1
# 238455  $40,000 to $49,999  $30,000 to $49,999      56        1
# 129126  $20,000 to $29,999  $20,000 to $29,999      56        1
# 238456  $75,000 to $99,999            $75,000+      56        1
# 238457  $30,000 to $39,999  $30,000 to $49,999      56        1
# 435939  $50,000 to $74,999  $50,000 to $74,999      56        1
# 365634  $40,000 to $49,999  $30,000 to $49,999      56        1
# 91622   $75,000 to $99,999            $75,000+      56        1
# 91623   $40,000 to $49,999  $30,000 to $49,999      56        1
# 91624   $30,000 to $39,999  $30,000 to $49,999      56        1
# 91625   $50,000 to $74,999  $50,000 to $74,999      56      NaN
# 91626   $20,000 to $29,999  $20,000 to $29,999      56      NaN
# 365635  $50,000 to $74,999  $50,000 to $74,999      56      NaN
# 91627   $50,000 to $74,999  $50,000 to $74,999      56      NaN
# 435940          DK\Refused            $75,000+      56      NaN
# 238458  $40,000 to $49,999  $30,000 to $49,999      56      NaN
# 91628   $10,000 to $19,999   less than $20,000      56      NaN
# 435941           $150,000+            $75,000+      56      NaN
# 382702  $50,000 to $74,999  $50,000 to $74,999      56      NaN
# 238459  $40,000 to $49,999  $30,000 to $49,999      56      NaN
# 91629   $50,000 to $74,999  $50,000 to $74,999      56      NaN
# 91630   $75,000 to $99,999            $75,000+      56        1
# 238460           $150,000+            $75,000+      56        1
# 91631   $50,000 to $74,999  $50,000 to $74,999      56        1
# 238461           $150,000+            $75,000+      56        1
# 435942   $100k to $149,999            $75,000+      56        1
# 91632   $50,000 to $74,999  $50,000 to $74,999      56        1
# 91633   $50,000 to $74,999  $50,000 to $74,999      56        1
# 129127  $20,000 to $29,999  $20,000 to $29,999      56        1
# 442259  $30,000 to $39,999  $30,000 to $49,999      56        1
# 365636  $10,000 to $19,999   less than $20,000      56      NaN
# 238462  $40,000 to $49,999  $30,000 to $49,999      56      NaN
# 382703  $50,000 to $74,999  $50,000 to $74,999      56      NaN
# 238463  $50,000 to $74,999  $50,000 to $74,999      56      NaN
# 91634   $30,000 to $39,999  $30,000 to $49,999      56      NaN
# 129128  $10,000 to $19,999   less than $20,000      56      NaN
# 238464  $30,000 to $39,999  $30,000 to $49,999      56        1
# 382704  $40,000 to $49,999  $30,000 to $49,999      56        1
# 91635   $75,000 to $99,999            $75,000+      56        1
# 238465  $50,000 to $74,999  $50,000 to $74,999      56        1
# 129129  $50,000 to $74,999  $50,000 to $74,999      56        1
# 238466  $75,000 to $99,999            $75,000+      56        1
# 365637  $20,000 to $29,999  $20,000 to $29,999      56        1
# 91636   $75,000 to $99,999            $75,000+      56        1
# 365638          DK\Refused          DK\Refused      56        1
# 91637   $40,000 to $49,999  $30,000 to $49,999      56        1
# 238467  $40,000 to $49,999  $30,000 to $49,999      56      NaN
# 129130          DK\Refused            $75,000+      56      NaN
# 365639  $10,000 to $19,999   less than $20,000      56      NaN
# 238468  $20,000 to $29,999  $20,000 to $29,999      56      NaN
# 129131   less than $10,000   less than $20,000      56      NaN
# 91638   $40,000 to $49,999  $30,000 to $49,999      56      NaN
# 238469  $30,000 to $39,999  $30,000 to $49,999      56      NaN
# 365640  $20,000 to $29,999  $20,000 to $29,999      56      NaN
# 365641  $75,000 to $99,999            $75,000+      56        1
# 238470  $30,000 to $39,999  $30,000 to $49,999      56        1
# 238471  $30,000 to $39,999  $30,000 to $49,999      56        1
# 365642  $20,000 to $29,999  $20,000 to $29,999      56        1
# 365643  $40,000 to $49,999  $30,000 to $49,999      56        1
# 365644  $10,000 to $19,999   less than $20,000      56        1
# 365645          DK\Refused          DK\Refused      56        1
# 238472  $10,000 to $19,999   less than $20,000      56        1
# 442260  $75,000 to $99,999            $75,000+      56        1
# 238473  $50,000 to $74,999  $50,000 to $74,999      56        1
# 238474   less than $10,000   less than $20,000      72        4
# 91639           DK\Refused          DK\Refused      78        3
#
#                               partysum  regvoter  fipsco state_name county_name  \
# 238442                        Rep/ln R       NaN      33    Wyoming    Sheridan
# 365625                        Rep/ln R         1      35    Wyoming    Sublette
# 435935                        Rep/ln R       NaN      35    Wyoming    Sublette
# 91615   Party or Partyln not available       NaN      35    Wyoming    Sublette
# 435936                        Dem/ln D         1      35    Wyoming    Sublette
# 365626                        Rep/ln R       NaN      35    Wyoming    Sublette
# 435937                        Dem/ln D         1      35    Wyoming    Sublette
# 91616                         Rep/ln R         1      35    Wyoming    Sublette
# 91617                         Rep/ln R         1      35    Wyoming    Sublette
# 91618                         Rep/ln R         1      35    Wyoming    Sublette
# 238443                        Rep/ln R         1      35    Wyoming    Sublette
# 238444                        Rep/ln R         1      35    Wyoming    Sublette
# 365627                        Rep/ln R       NaN      37    Wyoming  Sweetwater
# 238445                        Rep/ln R         1      37    Wyoming  Sweetwater
# 365628                        Dem/ln D         1      37    Wyoming  Sweetwater
# 365629                        Dem/ln D       NaN      37    Wyoming  Sweetwater
# 365630                        Rep/ln R       NaN      37    Wyoming  Sweetwater
# 91619                         Rep/ln R       NaN      37    Wyoming  Sweetwater
# 238446  Party or Partyln not available       NaN      37    Wyoming  Sweetwater
# 238447                        Dem/ln D       NaN      37    Wyoming  Sweetwater
# 365631                        Rep/ln R         1      37    Wyoming  Sweetwater
# 238448                        Dem/ln D         1      37    Wyoming  Sweetwater
# 365632                        Dem/ln D         1      37    Wyoming  Sweetwater
# 129124                        Rep/ln R       NaN      37    Wyoming  Sweetwater
# 91620                         Rep/ln R         1      37    Wyoming  Sweetwater
# 91621                       No leaning         1      37    Wyoming  Sweetwater
# 129125                        Dem/ln D       NaN      37    Wyoming  Sweetwater
# 238449                        Rep/ln R         1      37    Wyoming  Sweetwater
# 435938                        Dem/ln D         1      37    Wyoming  Sweetwater
# 238450                      No leaning       NaN      37    Wyoming  Sweetwater
# 365633                        Rep/ln R         1      37    Wyoming  Sweetwater
# 238451                        Rep/ln R         1      37    Wyoming  Sweetwater
# 238452                        Dem/ln D         1      37    Wyoming  Sweetwater
# 238453                        Rep/ln R         1      37    Wyoming  Sweetwater
# 238454                        Rep/ln R         1      37    Wyoming  Sweetwater
# 238455                        Rep/ln R         1      37    Wyoming  Sweetwater
# 129126                      No leaning       NaN      37    Wyoming  Sweetwater
# 238456                        Rep/ln R         1      37    Wyoming  Sweetwater
# 238457                        Rep/ln R         1      37    Wyoming  Sweetwater
# 435939                        Rep/ln R         1      37    Wyoming  Sweetwater
# 365634                      No leaning         1      37    Wyoming  Sweetwater
# 91622                         Dem/ln D         1      37    Wyoming  Sweetwater
# 91623                         Rep/ln R         1      37    Wyoming  Sweetwater
# 91624                         Dem/ln D         1      37    Wyoming  Sweetwater
# 91625                         Dem/ln D       NaN      39    Wyoming       Teton
# 91626                         Rep/ln R         1      39    Wyoming       Teton
# 365635                        Rep/ln R         1      39    Wyoming       Teton
# 91627   Party or Partyln not available       NaN      39    Wyoming       Teton
# 435940                        Dem/ln D         1      39    Wyoming       Teton
# 238458                        Rep/ln R         1      39    Wyoming       Teton
# 91628                         Dem/ln D       NaN      39    Wyoming       Teton
# 435941                        Rep/ln R         1      39    Wyoming       Teton
# 382702                        Rep/ln R         1      39    Wyoming       Teton
# 238459                        Dem/ln D         1      39    Wyoming       Teton
# 91629                         Rep/ln R         1      39    Wyoming       Teton
# 91630                         Rep/ln R         1      39    Wyoming       Teton
# 238460                      No leaning       NaN      39    Wyoming       Teton
# 91631                         Dem/ln D         1      39    Wyoming       Teton
# 238461                        Rep/ln R         1      39    Wyoming       Teton
# 435942                        Dem/ln D         1      39    Wyoming       Teton
# 91632                         Dem/ln D         1      39    Wyoming       Teton
# 91633                         Dem/ln D         1      39    Wyoming       Teton
# 129127                        Rep/ln R       NaN      39    Wyoming       Teton
# 442259                        Dem/ln D         1      39    Wyoming       Teton
# 365636                        Rep/ln R       NaN      41    Wyoming       Uinta
# 238462                        Rep/ln R         1      41    Wyoming       Uinta
# 382703                        Rep/ln R       NaN      41    Wyoming       Uinta
# 238463                        Rep/ln R         1      41    Wyoming       Uinta
# 91634                         Dem/ln D         1      41    Wyoming       Uinta
# 129128                        Dem/ln D       NaN      41    Wyoming       Uinta
# 238464                        Rep/ln R         1      41    Wyoming       Uinta
# 382704                        Rep/ln R       NaN      41    Wyoming       Uinta
# 91635                         Rep/ln R         1      41    Wyoming       Uinta
# 238465                        Rep/ln R         1      41    Wyoming       Uinta
# 129129                        Rep/ln R         1      41    Wyoming       Uinta
# 238466                        Rep/ln R         1      41    Wyoming       Uinta
# 365637                        Rep/ln R       NaN      41    Wyoming       Uinta
# 91636                         Rep/ln R         1      41    Wyoming       Uinta
# 365638                      No leaning         1      41    Wyoming       Uinta
# 91637                         Rep/ln R         1      41    Wyoming       Uinta
# 238467                        Rep/ln R       NaN      43    Wyoming    Washakie
# 129130  Party or Partyln not available       NaN      43    Wyoming    Washakie
# 365639                        Rep/ln R       NaN      43    Wyoming    Washakie
# 238468                        Rep/ln R         1      43    Wyoming    Washakie
# 129131                        Dem/ln D       NaN      43    Wyoming    Washakie
# 91638                         Rep/ln R         1      43    Wyoming    Washakie
# 238469                        Rep/ln R         1      43    Wyoming    Washakie
# 365640                      No leaning       NaN      43    Wyoming    Washakie
# 365641                        Rep/ln R         1      43    Wyoming    Washakie
# 238470                      No leaning         1      43    Wyoming    Washakie
# 238471                        Dem/ln D         1      43    Wyoming    Washakie
# 365642                        Dem/ln D         1      45    Wyoming      Weston
# 365643                        Dem/ln D         1      45    Wyoming      Weston
# 365644                        Rep/ln R         1      45    Wyoming      Weston
# 365645                      No leaning       NaN      45    Wyoming      Weston
# 238472                        Rep/ln R         1      45    Wyoming      Weston
# 442260                        Rep/ln R         1      45    Wyoming      Weston
# 238473                        Rep/ln R         1      45    Wyoming      Weston
# 238474                      No leaning       NaN      21        NaN         NaN
# 91639                         Dem/ln D         1      10        NaN         NaN
#
#                   partyln         race hisp     usr          party  \
# 238442  Missing/not asked        White   No  Rural      Republican
# 365625  Missing/not asked        White   No     NaN     Republican
# 435935    Lean Republican        White   No  Rural     Independent
# 91615                 NaN        White   No  Rural             NaN
# 435936  Missing/not asked        White   No  Rural        Democrat
# 365626  Missing/not asked        White   No  Rural      Republican
# 435937      Lean Democrat        White   No  Rural     Independent
# 91616   Missing/not asked        White   No  Rural      Republican
# 91617   Missing/not asked        White   No  Rural      Republican
# 91618   Missing/not asked        White   No  Rural      Republican
# 238443  Missing/not asked        White   No  Rural      Republican
# 238444  Missing/not asked   DK/Refused   No  Rural      Republican
# 365627    Lean Republican        White   No     NaN    Independent
# 238445  Missing/not asked        White   No  Rural      Republican
# 365628      Lean Democrat        White  Yes  Rural     Independent
# 365629  Missing/not asked        White   No  Rural        Democrat
# 365630  Missing/not asked        White   No  Rural      Republican
# 91619   Missing/not asked        White   No  Rural      Republican
# 238446                NaN   DK/Refused   No  Rural             NaN
# 238447  Missing/not asked        White   No  Rural        Democrat
# 365631    Lean Republican        White   No  Rural     Independent
# 238448  Missing/not asked        White   No  Rural        Democrat
# 365632  Missing/not asked        White   No  Rural        Democrat
# 129124    Lean Republican        White   No  Rural     Independent
# 91620   Missing/not asked        White   No  Rural      Republican
# 91621            Other/DK        White   No  Rural              DK
# 129125      Lean Democrat        White   No  Rural     Independent
# 238449    Lean Republican        White   No  Rural     Independent
# 435938  Missing/not asked        White   No  Rural        Democrat
# 238450           Other/DK        White   No  Rural     Independent
# 365633    Lean Republican        White   No  Rural     Independent
# 238451    Lean Republican        White   No  Rural     Independent
# 238452      Lean Democrat        White   No  Rural     Independent
# 238453  Missing/not asked        White   No  Rural      Republican
# 238454    Lean Republican  Other/Mixed   No  Rural     Independent
# 238455  Missing/not asked        White   No     NaN     Republican
# 129126           Other/DK        White  Yes  Rural     Independent
# 238456  Missing/not asked        White   No  Rural      Republican
# 238457    Lean Republican        White   No  Rural     Independent
# 435939  Missing/not asked        White   No  Rural      Republican
# 365634           Other/DK        White   No  Rural              DK
# 91622   Missing/not asked        White   No  Rural        Democrat
# 91623   Missing/not asked        White   No  Rural      Republican
# 91624   Missing/not asked        White  Yes  Rural        Democrat
# 91625   Missing/not asked        White   No     NaN       Democrat
# 91626   Missing/not asked        White  Yes     NaN     Republican
# 365635  Missing/not asked        White   No     NaN     Republican
# 91627                 NaN        White   No  Rural             NaN
# 435940      Lean Democrat  Other/Mixed   No  Rural     Independent
# 238458  Missing/not asked        White   No  Rural      Republican
# 91628       Lean Democrat        White   No  Rural     Independent
# 435941    Lean Republican        White   No  Rural     Independent
# 382702  Missing/not asked        White   No  Rural      Republican
# 238459  Missing/not asked        White   No  Rural        Democrat
# 91629     Lean Republican        White   No  Rural     Independent
# 91630   Missing/not asked        White   No  Rural      Republican
# 238460           Other/DK        White   No  Rural     Independent
# 91631   Missing/not asked        White   No  Rural        Democrat
# 238461  Missing/not asked        White   No  Rural      Republican
# 435942      Lean Democrat        White   No  Rural     Independent
# 91632   Missing/not asked        White   No  Rural        Democrat
# 91633   Missing/not asked        White   No  Rural        Democrat
# 129127    Lean Republican        White  Yes  Rural   No Preference
# 442259      Lean Democrat        White   No  Rural     Independent
# 365636  Missing/not asked        White   No  Rural      Republican
# 238462    Lean Republican  Other/Mixed  Yes     NaN    Independent
# 382703    Lean Republican        White   No  Rural   No Preference
# 238463  Missing/not asked  Other/Mixed   No     NaN     Republican
# 91634       Lean Democrat        White   No  Rural     Independent
# 129128      Lean Democrat        White   No  Rural     Independent
# 238464  Missing/not asked        White   No  Rural      Republican
# 382704  Missing/not asked        White   No  Rural      Republican
# 91635   Missing/not asked        White   No  Rural      Republican
# 238465  Missing/not asked        White   No  Rural      Republican
# 129129  Missing/not asked        White   No  Rural      Republican
# 238466    Lean Republican        White   No  Rural     Independent
# 365637    Lean Republican        White   No     NaN    Independent
# 91636   Missing/not asked        White   No  Rural      Republican
# 365638           Other/DK        White   No  Rural              DK
# 91637     Lean Republican        White   No  Rural     Independent
# 238467    Lean Republican        White   No  Rural     Independent
# 129130                NaN        White   No  Rural             NaN
# 365639  Missing/not asked        White   No  Rural      Republican
# 238468  Missing/not asked        White   No  Rural      Republican
# 129131      Lean Democrat        White  Yes     NaN    Independent
# 91638   Missing/not asked        White   No  Rural      Republican
# 238469  Missing/not asked  Other/Mixed   No  Rural      Republican
# 365640           Other/DK        White   No  Rural     Independent
# 365641  Missing/not asked        White   No  Rural      Republican
# 238470           Other/DK        White   No  Rural     Independent
# 238471  Missing/not asked   DK/Refused   No  Rural        Democrat
# 365642  Missing/not asked        White   No  Rural        Democrat
# 365643  Missing/not asked        White   No  Rural        Democrat
# 365644    Lean Republican        White   No  Rural     Independent
# 365645           Other/DK        White   No  Rural     Independent
# 238472  Missing/not asked        White   No  Rural      Republican
# 442260  Missing/not asked        White   No  Rural      Republican
# 238473    Lean Republican        White   No  Rural     Independent
# 238474           Other/DK        White  Yes     NaN             DK
# 91639   Missing/not asked        Black   No     NaN       Democrat
#
#                               educ
# 238442                Some College
# 365625        High school graduate
# 435935               Post-graduate
# 91615             College graduate
# 435936               Post-graduate
# 365626        High school graduate
# 435937               Post-graduate
# 91616             College graduate
# 91617             College graduate
# 91618             College graduate
# 238443                Some College
# 238444                Some College
# 365627        High school graduate
# 238445                Some College
# 365628        High school graduate
# 365629        High school graduate
# 365630        High school graduate
# 91619             College graduate
# 238446                Some College
# 238447                Some College
# 365631        High school graduate
# 238448                Some College
# 365632        High school graduate
# 129124     High school, incomplete
# 91620             College graduate
# 91621             College graduate
# 129125     High school, incomplete
# 238449                Some College
# 435938               Post-graduate
# 238450                Some College
# 365633        High school graduate
# 238451                Some College
# 238452                Some College
# 238453                Some College
# 238454                Some College
# 238455                Some College
# 129126     High school, incomplete
# 238456                Some College
# 238457                Some College
# 435939               Post-graduate
# 365634        High school graduate
# 91622             College graduate
# 91623             College graduate
# 91624             College graduate
# 91625             College graduate
# 91626             College graduate
# 365635        High school graduate
# 91627             College graduate
# 435940               Post-graduate
# 238458                Some College
# 91628             College graduate
# 435941               Post-graduate
# 382702  Business, Technical, Trade
# 238459                Some College
# 91629             College graduate
# 91630             College graduate
# 238460                Some College
# 91631             College graduate
# 238461                Some College
# 435942               Post-graduate
# 91632             College graduate
# 91633             College graduate
# 129127     High school, incomplete
# 442259        Post-graduate degree
# 365636        High school graduate
# 238462                Some College
# 382703  Business, Technical, Trade
# 238463                Some College
# 91634             College graduate
# 129128     High school, incomplete
# 238464                Some College
# 382704  Business, Technical, Trade
# 91635             College graduate
# 238465                Some College
# 129129     High school, incomplete
# 238466                Some College
# 365637        High school graduate
# 91636             College graduate
# 365638        High school graduate
# 91637             College graduate
# 238467                Some College
# 129130     High school, incomplete
# 365639        High school graduate
# 238468                Some College
# 129131     High school, incomplete
# 91638             College graduate
# 238469                Some College
# 365640        High school graduate
# 365641        High school graduate
# 238470                Some College
# 238471                Some College
# 365642        High school graduate
# 365643        High school graduate
# 365644        High school graduate
# 365645        High school graduate
# 238472                Some College
# 442260        Post-graduate degree
# 238473                Some College
# 238474                Some College
# 91639             College graduate
